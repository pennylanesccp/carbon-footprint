# %%
# tests/test_routes_provider_manual.py
# Run:  python -m tests.test_routes_provider_manual

import os, sys
import json
import time
import traceback

# Optional: load .env for local runs
try:
    from dotenv import load_dotenv
    load_dotenv()
except Exception:
    pass

# Choose the import that matches your project layout:
os.chdir("..")  # jump from tests/ to project root
sys.path.insert(0, os.getcwd())
from modules.routes_provider import ORSConfig, ORSClient
# from cabosupernet.routes_provider import ORSConfig, ORSClient

def jprint(obj) -> None:
    """Pretty-print dicts/lists like JSON."""
    print(json.dumps(obj, ensure_ascii=False, indent=2, sort_keys=True))

def run_case(label: str, origin, destination, **kwargs):
    """Run one routing case with timing and robust error display."""
    print("\n" + "=" * 80)
    print(f"{label}")
    print("-" * 80)
    print("origin:", origin)
    print("destination:", destination)
    t0 = time.time()
    try:
        resp = ors.route_road(origin, destination, **kwargs)
        elapsed = (time.time() - t0) * 1000
        print(f"\n✓ OK in {elapsed:.0f} ms — result:\n")
        jprint(resp)
    except Exception as e:
        elapsed = (time.time() - t0) * 1000
        print(f"\n✗ ERROR in {elapsed:.0f} ms — details:\n")
        # If it's an HTTP error, try to show server JSON/text body
        body = None
        resp = getattr(e, "response", None)
        if resp is not None:
            try:
                body = resp.json()
            except Exception:
                body = resp.text
        err_info = {
            "error_type": type(e).__name__,
            "http_status": getattr(resp, "status_code", None),
            "server_body": body,
            "exception_str": str(e),
        }
        jprint(err_info)
        print("\nTraceback (for debugging):")
        traceback.print_exc()

# Guard: require ORS_API_KEY
if not os.getenv("ORS_API_KEY"):
    raise SystemExit("Set ORS_API_KEY in your environment or .env before running this test.")

# Optional: bump logging from the client (INFO/DEBUG/WARNING/ERROR)
os.environ.setdefault("ORS_LOG_LEVEL", "INFO")

cfg = ORSConfig(default_country="BR")
ors = ORSClient(cfg)

# ──────────────────────────────────────────────────────────────────────────────
# Test cases
# ──────────────────────────────────────────────────────────────────────────────

# 1) Free-text address
run_case(
    "1) Free-text address",
    "Av. Paulista, 1578, São Paulo, SP",
    "Porto de Santos, Santos, SP",
)

# 2) CEP-only (postal code)
run_case(
    "2) CEP-only (postal code)",
    "01310-200",
    "11010-091",
)

# 3) City names
run_case(
    "3) City names",
    "São Paulo, SP",
    "Rio de Janeiro, RJ",
)

# 4) Coordinates (tuple) → to CEP
run_case(
    "4) Coordinates (tuple) → CEP",
    (-23.55052, -46.63331),
    "11010913",
)

# 5) Structured dict → explicit lat/lon
origin_struct = {
      "street": "Avenida Paulista"
    , "housenumber": "1578"
    , "locality": "São Paulo"
    , "region": "SP"
    , "postalcode": "01310-200"
    , "country": "BR"
}
run_case(
    "5) Structured dict",
    origin_struct,
    {"lat": -23.9608, "lon": -46.3336, "label": "Santos Ponta da Praia"},
)
# Out:
# [10:07:23] INFO cabosupernet.routes_provider | GEOCODE text='Av. Paulista, 1578, São Paulo, SP' country=BR size=1
# ================================================================================
# 1) Free-text address
# --------------------------------------------------------------------------------
# origin: Av. Paulista, 1578, São Paulo, SP
# destination: Porto de Santos, Santos, SP
# [10:07:30] INFO cabosupernet.routes_provider | RESOLVE (text) -> {'lat': -23.555036, 'lon': -46.663479, 'label': 'Avenida Paulista, São Paulo, Brazil'}
# [10:07:30] INFO cabosupernet.routes_provider | GEOCODE text='Porto de Santos, Santos, SP' country=BR size=1
# [10:07:35] INFO cabosupernet.routes_provider | RESOLVE (text) -> {'lat': -23.932511, 'lon': -46.324739, 'label': 'Alfandega do Porto de Santos, Santos, SP, Brazil'}
# [10:07:35] INFO cabosupernet.routes_provider | ROUTE try1 driving-car coords=[[-46.663479, -23.555036], [-46.324739, -23.932511]]
# [10:07:40] INFO cabosupernet.routes_provider | ROUTE OK km=77.39 hrs=1.23
# [10:07:40] INFO cabosupernet.routes_provider | GEOCODE structured params={"country": "BR", "postalcode": "01310200", "size": 1}
# ✓ OK in 16849 ms — result:
#
# {
#   "destination": {
#     "label": "Alfandega do Porto de Santos, Santos, SP, Brazil",
#     "lat": -23.932511,
#     "lon": -46.324739
#   },
#   "distance_m": 77393.1,
#   "duration_s": 4421.9,
#   "origin": {
#     "label": "Avenida Paulista, São Paulo, Brazil",
#     "lat": -23.555036,
#     "lon": -46.663479
#   },
#   "segments": [
#     {
#       "distance": 77393.1,
#       "duration": 4421.9,
#       "steps": [
#         {
#           "distance": 135.9,
#           "duration": 25.3,
#           "instruction": "Head northwest on Avenida Paulista",
#           "name": "Avenida Paulista",
#           "type": 11,
#           "way_points": [
#             0,
#             9
#           ]
#         },
#         {
#           "distance": 43.8,
#           "duration": 12.9,
#           "instruction": "Turn left onto Praça Marechal Cordeiro de Farias",
#           "name": "Praça Marechal Cordeiro de Farias",
#           "type": 0,
#           "way_points": [
#             9,
#             13
#           ]
#         },
#         {
#           "distance": 1033.5,
#           "duration": 125.2,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             13,
#             30
#           ]
#         },
#         {
#           "distance": 687.7,
#           "duration": 82.7,
#           "instruction": "Turn left onto Rua Oscar Freire",
#           "name": "Rua Oscar Freire",
#           "type": 0,
#           "way_points": [
#             30,
#             37
#           ]
#         },
#         {
#           "distance": 721.3,
#           "duration": 84.2,
#           "instruction": "Turn right onto Rua Augusta",
#           "name": "Rua Augusta",
#           "type": 1,
#           "way_points": [
#             37,
#             47
#           ]
#         },
#         {
#           "distance": 2726.5,
#           "duration": 266.7,
#           "instruction": "Turn left onto Avenida Brasil",
#           "name": "Avenida Brasil",
#           "type": 0,
#           "way_points": [
#             47,
#             94
#           ]
#         },
#         {
#           "distance": 176.5,
#           "duration": 24.8,
#           "instruction": "Continue straight onto Avenida Pedro Álvares Cabral",
#           "name": "Avenida Pedro Álvares Cabral",
#           "type": 6,
#           "way_points": [
#             94,
#             98
#           ]
#         },
#         {
#           "distance": 2239.7,
#           "duration": 194.7,
#           "instruction": "Continue straight onto Avenida Pedro Álvares Cabral",
#           "name": "Avenida Pedro Álvares Cabral",
#           "type": 6,
#           "way_points": [
#             98,
#             136
#           ]
#         },
#         {
#           "distance": 2469.4,
#           "duration": 250.2,
#           "instruction": "Turn left onto Viaduto República Árabe Síria",
#           "name": "Viaduto República Árabe Síria",
#           "type": 0,
#           "way_points": [
#             136,
#             166
#           ]
#         },
#         {
#           "distance": 335.9,
#           "duration": 44.2,
#           "instruction": "Turn left onto Avenida Jabaquara",
#           "name": "Avenida Jabaquara",
#           "type": 0,
#           "way_points": [
#             166,
#             173
#           ]
#         },
#         {
#           "distance": 654.5,
#           "duration": 67.5,
#           "instruction": "Turn sharp right onto Avenida Doutor Hugo Beolchi",
#           "name": "Avenida Doutor Hugo Beolchi",
#           "type": 3,
#           "way_points": [
#             173,
#             186
#           ]
#         },
#         {
#           "distance": 46.2,
#           "duration": 8.3,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             186,
#             189
#           ]
#         },
#         {
#           "distance": 1022.5,
#           "duration": 96.0,
#           "instruction": "Keep right onto Avenida Diederichsen",
#           "name": "Avenida Diederichsen",
#           "type": 13,
#           "way_points": [
#             189,
#             213
#           ]
#         },
#         {
#           "distance": 221.5,
#           "duration": 19.9,
#           "instruction": "Turn right onto Rua Edgard Pereira",
#           "name": "Rua Edgard Pereira",
#           "type": 1,
#           "way_points": [
#             213,
#             215
#           ]
#         },
#         {
#           "distance": 97.4,
#           "duration": 11.7,
#           "instruction": "Turn left onto Rua Áurea Lejeune",
#           "name": "Rua Áurea Lejeune",
#           "type": 0,
#           "way_points": [
#             215,
#             216
#           ]
#         },
#         {
#           "distance": 52089.5,
#           "duration": 2370.4,
#           "instruction": "Turn right",
#           "name": "-",
#           "type": 1,
#           "way_points": [
#             216,
#             561
#           ]
#         },
#         {
#           "distance": 3114.2,
#           "duration": 188.8,
#           "instruction": "Keep right onto SPI-059/150",
#           "name": "SPI-059/150",
#           "type": 13,
#           "way_points": [
#             561,
#             599
#           ]
#         },
#         {
#           "distance": 5948.9,
#           "duration": 258.7,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             599,
#             638
#           ]
#         },
#         {
#           "distance": 2023.5,
#           "duration": 180.7,
#           "instruction": "Keep right onto Avenida Martins Fontes",
#           "name": "Avenida Martins Fontes",
#           "type": 13,
#           "way_points": [
#             638,
#             674
#           ]
#         },
#         {
#           "distance": 480.1,
#           "duration": 41.5,
#           "instruction": "Turn sharp left onto Rua Senador Christiano Ottoni",
#           "name": "Rua Senador Christiano Ottoni",
#           "type": 2,
#           "way_points": [
#             674,
#             689
#           ]
#         },
#         {
#           "distance": 1124.4,
#           "duration": 67.5,
#           "instruction": "Turn right onto Avenida Xavier da Silveira",
#           "name": "Avenida Xavier da Silveira",
#           "type": 1,
#           "way_points": [
#             689,
#             708
#           ]
#         },
#         {
#           "distance": 0.0,
#           "duration": 0.0,
#           "instruction": "Arrive at Avenida Xavier da Silveira, on the right",
#           "name": "-",
#           "type": 10,
#           "way_points": [
#             708,
#             708
#           ]
#         }
#       ]
#     }
#   ]
# }
#
# ================================================================================
# 2) CEP-only (postal code)
# --------------------------------------------------------------------------------
# origin: 01310-200
# destination: 11010-091
# [10:07:41] INFO cabosupernet.routes_provider | ViaCEP GET https://viacep.com.br/ws/01310200/json/
# [10:07:42] INFO cabosupernet.routes_provider | RESOLVE (CEP ViaCEP->text) query='Avenida Paulista, Bela Vista, São Paulo, SP'
# [10:07:42] INFO cabosupernet.routes_provider | GEOCODE text='Avenida Paulista, Bela Vista, São Paulo, SP' country=BR size=1
# [10:07:43] INFO cabosupernet.routes_provider | RESOLVE (CEP via ViaCEP) -> {'lat': -23.563498, 'lon': -46.653985, 'label': 'Ciclovia da Avenida Paulista, São Paulo, Brazil'}
# [10:07:43] INFO cabosupernet.routes_provider | GEOCODE structured params={"country": "BR", "postalcode": "11010091", "size": 1}
# [10:07:48] INFO cabosupernet.routes_provider | ViaCEP GET https://viacep.com.br/ws/11010091/json/
# [10:07:48] INFO cabosupernet.routes_provider | RESOLVE (CEP ViaCEP->text) query='Rua Frei Gaspar, Centro, Santos, SP'
# [10:07:48] INFO cabosupernet.routes_provider | GEOCODE text='Rua Frei Gaspar, Centro, Santos, SP' country=BR size=1
# [10:07:48] INFO cabosupernet.routes_provider | RESOLVE (CEP via ViaCEP) -> {'lat': -23.935639, 'lon': -46.325439, 'label': 'Centro, Santos, SP, Brazil'}
# [10:07:48] INFO cabosupernet.routes_provider | ROUTE try1 driving-car coords=[[-46.653985, -23.563498], [-46.325439, -23.935639]]
# [10:07:49] INFO cabosupernet.routes_provider | ROUTE OK km=75.83 hrs=1.21
# [10:07:49] INFO cabosupernet.routes_provider | GEOCODE text='São Paulo, SP' country=BR size=1
# ✓ OK in 8661 ms — result:
#
# {
#   "destination": {
#     "label": "Centro, Santos, SP, Brazil",
#     "lat": -23.935639,
#     "lon": -46.325439
#   },
#   "distance_m": 75826.3,
#   "duration_s": 4356.7,
#   "origin": {
#     "label": "Ciclovia da Avenida Paulista, São Paulo, Brazil",
#     "lat": -23.563498,
#     "lon": -46.653985
#   },
#   "segments": [
#     {
#       "distance": 75826.3,
#       "duration": 4356.7,
#       "steps": [
#         {
#           "distance": 429.3,
#           "duration": 52.2,
#           "instruction": "Head northwest on Avenida Paulista",
#           "name": "Avenida Paulista",
#           "type": 11,
#           "way_points": [
#             0,
#             6
#           ]
#         },
#         {
#           "distance": 4344.1,
#           "duration": 514.1,
#           "instruction": "Continue straight onto Avenida Paulista",
#           "name": "Avenida Paulista",
#           "type": 6,
#           "way_points": [
#             6,
#             70
#           ]
#         },
#         {
#           "distance": 1368.3,
#           "duration": 182.8,
#           "instruction": "Keep left onto Rua Domingos de Morais",
#           "name": "Rua Domingos de Morais",
#           "type": 12,
#           "way_points": [
#             70,
#             98
#           ]
#         },
#         {
#           "distance": 952.4,
#           "duration": 82.9,
#           "instruction": "Turn left onto Rua Luis Góis",
#           "name": "Rua Luis Góis",
#           "type": 0,
#           "way_points": [
#             98,
#             113
#           ]
#         },
#         {
#           "distance": 159.2,
#           "duration": 14.3,
#           "instruction": "Turn right onto Rua Santo Irineu",
#           "name": "Rua Santo Irineu",
#           "type": 1,
#           "way_points": [
#             113,
#             115
#           ]
#         },
#         {
#           "distance": 110.8,
#           "duration": 11.4,
#           "instruction": "Turn left onto Rua Dom Bernardo Nogueira",
#           "name": "Rua Dom Bernardo Nogueira",
#           "type": 0,
#           "way_points": [
#             115,
#             116
#           ]
#         },
#         {
#           "distance": 55458.7,
#           "duration": 2692.4,
#           "instruction": "Turn right onto Avenida Professor Abraão de Morais, SP-160",
#           "name": "Avenida Professor Abraão de Morais, SP-160",
#           "type": 1,
#           "way_points": [
#             116,
#             512
#           ]
#         },
#         {
#           "distance": 3114.2,
#           "duration": 188.8,
#           "instruction": "Keep right onto SPI-059/150",
#           "name": "SPI-059/150",
#           "type": 13,
#           "way_points": [
#             512,
#             550
#           ]
#         },
#         {
#           "distance": 5948.9,
#           "duration": 258.7,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             550,
#             589
#           ]
#         },
#         {
#           "distance": 2023.5,
#           "duration": 180.7,
#           "instruction": "Keep right onto Avenida Martins Fontes",
#           "name": "Avenida Martins Fontes",
#           "type": 13,
#           "way_points": [
#             589,
#             625
#           ]
#         },
#         {
#           "distance": 480.1,
#           "duration": 41.5,
#           "instruction": "Turn sharp left onto Rua Senador Christiano Ottoni",
#           "name": "Rua Senador Christiano Ottoni",
#           "type": 2,
#           "way_points": [
#             625,
#             640
#           ]
#         },
#         {
#           "distance": 907.6,
#           "duration": 54.5,
#           "instruction": "Turn right onto Avenida Xavier da Silveira",
#           "name": "Avenida Xavier da Silveira",
#           "type": 1,
#           "way_points": [
#             640,
#             657
#           ]
#         },
#         {
#           "distance": 63.9,
#           "duration": 15.3,
#           "instruction": "Turn right onto Praça Barão do Rio Branco",
#           "name": "Praça Barão do Rio Branco",
#           "type": 1,
#           "way_points": [
#             657,
#             658
#           ]
#         },
#         {
#           "distance": 16.7,
#           "duration": 4.0,
#           "instruction": "Keep left onto Praça Barão do Rio Branco",
#           "name": "Praça Barão do Rio Branco",
#           "type": 12,
#           "way_points": [
#             658,
#             659
#           ]
#         },
#         {
#           "distance": 163.9,
#           "duration": 39.3,
#           "instruction": "Turn left onto Praça República",
#           "name": "Praça República",
#           "type": 0,
#           "way_points": [
#             659,
#             662
#           ]
#         },
#         {
#           "distance": 284.7,
#           "duration": 23.7,
#           "instruction": "Turn right onto Avenida Senador Feijó",
#           "name": "Avenida Senador Feijó",
#           "type": 1,
#           "way_points": [
#             662,
#             665
#           ]
#         },
#         {
#           "distance": 0.0,
#           "duration": 0.0,
#           "instruction": "Arrive at Avenida Senador Feijó, on the left",
#           "name": "-",
#           "type": 10,
#           "way_points": [
#             665,
#             665
#           ]
#         }
#       ]
#     }
#   ]
# }
#
# ================================================================================
# 3) City names
# --------------------------------------------------------------------------------
# origin: São Paulo, SP
# destination: Rio de Janeiro, RJ
# [10:07:49] INFO cabosupernet.routes_provider | RESOLVE (text) -> {'lat': -23.570533, 'lon': -46.663713, 'label': 'São Paulo, Brazil'}
# [10:07:49] INFO cabosupernet.routes_provider | GEOCODE text='Rio de Janeiro, RJ' country=BR size=1
# [10:07:50] INFO cabosupernet.routes_provider | RESOLVE (text) -> {'lat': -22.935024, 'lon': -43.518246, 'label': 'Rio de Janeiro, Brazil'}
# [10:07:50] INFO cabosupernet.routes_provider | ROUTE try1 driving-car coords=[[-46.663713, -23.570533], [-43.518246, -22.935024]]
# [10:07:50] INFO cabosupernet.routes_provider | ROUTE OK km=405.46 hrs=5.33
# [10:07:50] INFO cabosupernet.routes_provider | RESOLVE (tuple/list) -> {'lat': -23.55052, 'lon': -46.63331, 'label': '-23.550520,-46.633310'}
# [10:07:50] INFO cabosupernet.routes_provider | GEOCODE structured params={"country": "BR", "postalcode": "11010913", "size": 1}
# ✓ OK in 1542 ms — result:
#
# {
#   "destination": {
#     "label": "Rio de Janeiro, Brazil",
#     "lat": -22.935024,
#     "lon": -43.518246
#   },
#   "distance_m": 405461.5,
#   "duration_s": 19172.8,
#   "origin": {
#     "label": "São Paulo, Brazil",
#     "lat": -23.570533,
#     "lon": -46.663713
#   },
#   "segments": [
#     {
#       "distance": 405461.5,
#       "duration": 19172.8,
#       "steps": [
#         {
#           "distance": 82.2,
#           "duration": 19.7,
#           "instruction": "Head northeast on Rua Paraguai",
#           "name": "Rua Paraguai",
#           "type": 11,
#           "way_points": [
#             0,
#             1
#           ]
#         },
#         {
#           "distance": 74.6,
#           "duration": 17.9,
#           "instruction": "Turn right onto Rua Presidente Prudente",
#           "name": "Rua Presidente Prudente",
#           "type": 1,
#           "way_points": [
#             1,
#             2
#           ]
#         },
#         {
#           "distance": 328.2,
#           "duration": 32.1,
#           "instruction": "Turn right onto Avenida Nove de Julho",
#           "name": "Avenida Nove de Julho",
#           "type": 1,
#           "way_points": [
#             2,
#             6
#           ]
#         },
#         {
#           "distance": 6750.5,
#           "duration": 679.1,
#           "instruction": "Continue straight onto Avenida Nove de Julho",
#           "name": "Avenida Nove de Julho",
#           "type": 6,
#           "way_points": [
#             6,
#             90
#           ]
#         },
#         {
#           "distance": 17.8,
#           "duration": 1.6,
#           "instruction": "Turn sharp right onto Avenida do Estado, BR-050",
#           "name": "Avenida do Estado, BR-050",
#           "type": 3,
#           "way_points": [
#             90,
#             91
#           ]
#         },
#         {
#           "distance": 397.9,
#           "duration": 60.5,
#           "instruction": "Turn sharp left onto Avenida Santos Dumont",
#           "name": "Avenida Santos Dumont",
#           "type": 2,
#           "way_points": [
#             91,
#             101
#           ]
#         },
#         {
#           "distance": 4110.6,
#           "duration": 203.9,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             101,
#             166
#           ]
#         },
#         {
#           "distance": 86422.7,
#           "duration": 3495.6,
#           "instruction": "Keep left onto Rodovia Presidente Dutra, BR-116",
#           "name": "Rodovia Presidente Dutra, BR-116",
#           "type": 12,
#           "way_points": [
#             166,
#             655
#           ]
#         },
#         {
#           "distance": 206452.7,
#           "duration": 8051.2,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             655,
#             2112
#           ]
#         },
#         {
#           "distance": 64132.5,
#           "duration": 3326.5,
#           "instruction": "Continue straight onto Rodovia Presidente Dutra, BR-116, KM-272",
#           "name": "Rodovia Presidente Dutra, BR-116, KM-272",
#           "type": 6,
#           "way_points": [
#             2112,
#             3138
#           ]
#         },
#         {
#           "distance": 556.3,
#           "duration": 61.5,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             3138,
#             3149
#           ]
#         },
#         {
#           "distance": 17329.6,
#           "duration": 1464.8,
#           "instruction": "Turn slight right onto Rodovia Luiz Henrique Rezende Novaes, BR-465",
#           "name": "Rodovia Luiz Henrique Rezende Novaes, BR-465",
#           "type": 5,
#           "way_points": [
#             3149,
#             3404
#           ]
#         },
#         {
#           "distance": 86.7,
#           "duration": 12.5,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             3404,
#             3408
#           ]
#         },
#         {
#           "distance": 3914.1,
#           "duration": 430.9,
#           "instruction": "Turn slight right onto Rodovia Luiz Henrique Rezende Novaes, BR-465",
#           "name": "Rodovia Luiz Henrique Rezende Novaes, BR-465",
#           "type": 5,
#           "way_points": [
#             3408,
#             3487
#           ]
#         },
#         {
#           "distance": 242.3,
#           "duration": 20.8,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             3487,
#             3497
#           ]
#         },
#         {
#           "distance": 7686.4,
#           "duration": 581.4,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             3497,
#             3642
#           ]
#         },
#         {
#           "distance": 715.7,
#           "duration": 80.9,
#           "instruction": "Keep right onto Avenida Cesário de Melo",
#           "name": "Avenida Cesário de Melo",
#           "type": 13,
#           "way_points": [
#             3642,
#             3658
#           ]
#         },
#         {
#           "distance": 744.0,
#           "duration": 59.5,
#           "instruction": "Keep right onto Avenida Dom Sebastião I",
#           "name": "Avenida Dom Sebastião I",
#           "type": 13,
#           "way_points": [
#             3658,
#             3668
#           ]
#         },
#         {
#           "distance": 775.4,
#           "duration": 70.0,
#           "instruction": "Turn left onto Estrada do Cabuçu",
#           "name": "Estrada do Cabuçu",
#           "type": 0,
#           "way_points": [
#             3668,
#             3680
#           ]
#         },
#         {
#           "distance": 3207.7,
#           "duration": 284.1,
#           "instruction": "Continue straight onto Estrada do Cabuçu",
#           "name": "Estrada do Cabuçu",
#           "type": 6,
#           "way_points": [
#             3680,
#             3751
#           ]
#         },
#         {
#           "distance": 1184.2,
#           "duration": 187.5,
#           "instruction": "Turn right onto Caminho do Morro dos Caboclos",
#           "name": "Caminho do Morro dos Caboclos",
#           "type": 1,
#           "way_points": [
#             3751,
#             3790
#           ]
#         },
#         {
#           "distance": 7.5,
#           "duration": 1.8,
#           "instruction": "Turn slight right onto Caminho do Morro dos Caboclos",
#           "name": "Caminho do Morro dos Caboclos",
#           "type": 5,
#           "way_points": [
#             3790,
#             3791
#           ]
#         },
#         {
#           "distance": 241.9,
#           "duration": 29.0,
#           "instruction": "Turn slight left",
#           "name": "-",
#           "type": 4,
#           "way_points": [
#             3791,
#             3805
#           ]
#         },
#         {
#           "distance": 0.0,
#           "duration": 0.0,
#           "instruction": "Arrive at your destination, on the left",
#           "name": "-",
#           "type": 10,
#           "way_points": [
#             3805,
#             3805
#           ]
#         }
#       ]
#     }
#   ]
# }
#
# ================================================================================
# 4) Coordinates (tuple) → CEP
# --------------------------------------------------------------------------------
# origin: (-23.55052, -46.63331)
# destination: 11010913
# [10:07:51] INFO cabosupernet.routes_provider | ViaCEP GET https://viacep.com.br/ws/11010913/json/
# [10:07:51] INFO cabosupernet.routes_provider | RESOLVE (CEP ViaCEP->text) query='Rua Martin Affonso, Centro, Santos, SP'
# [10:07:51] INFO cabosupernet.routes_provider | GEOCODE text='Rua Martin Affonso, Centro, Santos, SP' country=BR size=1
# [10:07:51] INFO cabosupernet.routes_provider | RESOLVE (CEP via ViaCEP) -> {'lat': -23.935639, 'lon': -46.325439, 'label': 'Centro, Santos, SP, Brazil'}
# [10:07:51] INFO cabosupernet.routes_provider | ROUTE try1 driving-car coords=[[-46.63331, -23.55052], [-46.325439, -23.935639]]
# [10:07:52] INFO cabosupernet.routes_provider | ROUTE OK km=76.74 hrs=1.22
# [10:07:52] INFO cabosupernet.routes_provider | GEOCODE structured params={"address": "1578 Avenida Paulista", "country": "BR", "locality": "São Paulo", "postalcode": "01310-200", "region": "SP", "size": 1}
# ✓ OK in 1339 ms — result:
#
# {
#   "destination": {
#     "label": "Centro, Santos, SP, Brazil",
#     "lat": -23.935639,
#     "lon": -46.325439
#   },
#   "distance_m": 76737.4,
#   "duration_s": 4385.9,
#   "origin": {
#     "label": "-23.550520,-46.633310",
#     "lat": -23.55052,
#     "lon": -46.63331
#   },
#   "segments": [
#     {
#       "distance": 76737.4,
#       "duration": 4385.9,
#       "steps": [
#         {
#           "distance": 145.7,
#           "duration": 35.0,
#           "instruction": "Head south on Praça da Sé",
#           "name": "Praça da Sé",
#           "type": 11,
#           "way_points": [
#             0,
#             4
#           ]
#         },
#         {
#           "distance": 164.0,
#           "duration": 22.0,
#           "instruction": "Turn left onto Praça Doutor João Mendes",
#           "name": "Praça Doutor João Mendes",
#           "type": 0,
#           "way_points": [
#             4,
#             8
#           ]
#         },
#         {
#           "distance": 579.3,
#           "duration": 66.4,
#           "instruction": "Turn slight left onto Rua Tabatinguera",
#           "name": "Rua Tabatinguera",
#           "type": 4,
#           "way_points": [
#             8,
#             19
#           ]
#         },
#         {
#           "distance": 22.4,
#           "duration": 2.3,
#           "instruction": "Turn right onto Rua Dom Pedro II",
#           "name": "Rua Dom Pedro II",
#           "type": 1,
#           "way_points": [
#             19,
#             20
#           ]
#         },
#         {
#           "distance": 2179.6,
#           "duration": 194.9,
#           "instruction": "Keep left onto Avenida do Estado",
#           "name": "Avenida do Estado",
#           "type": 12,
#           "way_points": [
#             20,
#             53
#           ]
#         },
#         {
#           "distance": 110.6,
#           "duration": 22.9,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             53,
#             60
#           ]
#         },
#         {
#           "distance": 1547.3,
#           "duration": 156.9,
#           "instruction": "Turn left onto Avenida Dom Pedro I",
#           "name": "Avenida Dom Pedro I",
#           "type": 0,
#           "way_points": [
#             60,
#             82
#           ]
#         },
#         {
#           "distance": 58985.0,
#           "duration": 3079.0,
#           "instruction": "Turn right onto Avenida Doutor Ricardo Jafet, SP-160",
#           "name": "Avenida Doutor Ricardo Jafet, SP-160",
#           "type": 1,
#           "way_points": [
#             82,
#             541
#           ]
#         },
#         {
#           "distance": 3114.2,
#           "duration": 188.8,
#           "instruction": "Keep right onto SPI-059/150",
#           "name": "SPI-059/150",
#           "type": 13,
#           "way_points": [
#             541,
#             579
#           ]
#         },
#         {
#           "distance": 5948.9,
#           "duration": 258.7,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             579,
#             618
#           ]
#         },
#         {
#           "distance": 2023.5,
#           "duration": 180.7,
#           "instruction": "Keep right onto Avenida Martins Fontes",
#           "name": "Avenida Martins Fontes",
#           "type": 13,
#           "way_points": [
#             618,
#             654
#           ]
#         },
#         {
#           "distance": 480.1,
#           "duration": 41.5,
#           "instruction": "Turn sharp left onto Rua Senador Christiano Ottoni",
#           "name": "Rua Senador Christiano Ottoni",
#           "type": 2,
#           "way_points": [
#             654,
#             669
#           ]
#         },
#         {
#           "distance": 907.6,
#           "duration": 54.5,
#           "instruction": "Turn right onto Avenida Xavier da Silveira",
#           "name": "Avenida Xavier da Silveira",
#           "type": 1,
#           "way_points": [
#             669,
#             686
#           ]
#         },
#         {
#           "distance": 63.9,
#           "duration": 15.3,
#           "instruction": "Turn right onto Praça Barão do Rio Branco",
#           "name": "Praça Barão do Rio Branco",
#           "type": 1,
#           "way_points": [
#             686,
#             687
#           ]
#         },
#         {
#           "distance": 16.7,
#           "duration": 4.0,
#           "instruction": "Keep left onto Praça Barão do Rio Branco",
#           "name": "Praça Barão do Rio Branco",
#           "type": 12,
#           "way_points": [
#             687,
#             688
#           ]
#         },
#         {
#           "distance": 163.9,
#           "duration": 39.3,
#           "instruction": "Turn left onto Praça República",
#           "name": "Praça República",
#           "type": 0,
#           "way_points": [
#             688,
#             691
#           ]
#         },
#         {
#           "distance": 284.7,
#           "duration": 23.7,
#           "instruction": "Turn right onto Avenida Senador Feijó",
#           "name": "Avenida Senador Feijó",
#           "type": 1,
#           "way_points": [
#             691,
#             694
#           ]
#         },
#         {
#           "distance": 0.0,
#           "duration": 0.0,
#           "instruction": "Arrive at Avenida Senador Feijó, on the left",
#           "name": "-",
#           "type": 10,
#           "way_points": [
#             694,
#             694
#           ]
#         }
#       ]
#     }
#   ]
# }
#
# ================================================================================
# 5) Structured dict
# --------------------------------------------------------------------------------
# origin: {'street': 'Avenida Paulista', 'housenumber': '1578', 'locality': 'São Paulo', 'region': 'SP', 'postalcode': '01310-200', 'country': 'BR'}
# destination: {'lat': -23.9608, 'lon': -46.3336, 'label': 'Santos Ponta da Praia'}
# [10:07:56] INFO cabosupernet.routes_provider | RESOLVE (structured dict) -> {'lat': -23.555036, 'lon': -46.663479, 'label': 'Avenida Paulista, São Paulo, Brazil'}
# [10:07:56] INFO cabosupernet.routes_provider | RESOLVE (dict lat/lon) -> {'lat': -23.9608, 'lon': -46.3336, 'label': 'Santos Ponta da Praia'}
# [10:07:56] INFO cabosupernet.routes_provider | ROUTE try1 driving-car coords=[[-46.663479, -23.555036], [-46.3336, -23.9608]]
# [10:07:56] INFO cabosupernet.routes_provider | ROUTE OK km=78.7 hrs=1.31
# ✓ OK in 4851 ms — result:
#
# {
#   "destination": {
#     "label": "Santos Ponta da Praia",
#     "lat": -23.9608,
#     "lon": -46.3336
#   },
#   "distance_m": 78704.9,
#   "duration_s": 4719.6,
#   "origin": {
#     "label": "Avenida Paulista, São Paulo, Brazil",
#     "lat": -23.555036,
#     "lon": -46.663479
#   },
#   "segments": [
#     {
#       "distance": 78704.9,
#       "duration": 4719.6,
#       "steps": [
#         {
#           "distance": 135.9,
#           "duration": 25.3,
#           "instruction": "Head northwest on Avenida Paulista",
#           "name": "Avenida Paulista",
#           "type": 11,
#           "way_points": [
#             0,
#             9
#           ]
#         },
#         {
#           "distance": 43.8,
#           "duration": 12.9,
#           "instruction": "Turn left onto Praça Marechal Cordeiro de Farias",
#           "name": "Praça Marechal Cordeiro de Farias",
#           "type": 0,
#           "way_points": [
#             9,
#             13
#           ]
#         },
#         {
#           "distance": 1033.5,
#           "duration": 125.2,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             13,
#             30
#           ]
#         },
#         {
#           "distance": 687.7,
#           "duration": 82.7,
#           "instruction": "Turn left onto Rua Oscar Freire",
#           "name": "Rua Oscar Freire",
#           "type": 0,
#           "way_points": [
#             30,
#             37
#           ]
#         },
#         {
#           "distance": 721.3,
#           "duration": 84.2,
#           "instruction": "Turn right onto Rua Augusta",
#           "name": "Rua Augusta",
#           "type": 1,
#           "way_points": [
#             37,
#             47
#           ]
#         },
#         {
#           "distance": 2726.5,
#           "duration": 266.7,
#           "instruction": "Turn left onto Avenida Brasil",
#           "name": "Avenida Brasil",
#           "type": 0,
#           "way_points": [
#             47,
#             94
#           ]
#         },
#         {
#           "distance": 176.5,
#           "duration": 24.8,
#           "instruction": "Continue straight onto Avenida Pedro Álvares Cabral",
#           "name": "Avenida Pedro Álvares Cabral",
#           "type": 6,
#           "way_points": [
#             94,
#             98
#           ]
#         },
#         {
#           "distance": 2239.7,
#           "duration": 194.7,
#           "instruction": "Continue straight onto Avenida Pedro Álvares Cabral",
#           "name": "Avenida Pedro Álvares Cabral",
#           "type": 6,
#           "way_points": [
#             98,
#             136
#           ]
#         },
#         {
#           "distance": 2469.4,
#           "duration": 250.2,
#           "instruction": "Turn left onto Viaduto República Árabe Síria",
#           "name": "Viaduto República Árabe Síria",
#           "type": 0,
#           "way_points": [
#             136,
#             166
#           ]
#         },
#         {
#           "distance": 335.9,
#           "duration": 44.2,
#           "instruction": "Turn left onto Avenida Jabaquara",
#           "name": "Avenida Jabaquara",
#           "type": 0,
#           "way_points": [
#             166,
#             173
#           ]
#         },
#         {
#           "distance": 654.5,
#           "duration": 67.5,
#           "instruction": "Turn sharp right onto Avenida Doutor Hugo Beolchi",
#           "name": "Avenida Doutor Hugo Beolchi",
#           "type": 3,
#           "way_points": [
#             173,
#             186
#           ]
#         },
#         {
#           "distance": 46.2,
#           "duration": 8.3,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             186,
#             189
#           ]
#         },
#         {
#           "distance": 1022.5,
#           "duration": 96.0,
#           "instruction": "Keep right onto Avenida Diederichsen",
#           "name": "Avenida Diederichsen",
#           "type": 13,
#           "way_points": [
#             189,
#             213
#           ]
#         },
#         {
#           "distance": 221.5,
#           "duration": 19.9,
#           "instruction": "Turn right onto Rua Edgard Pereira",
#           "name": "Rua Edgard Pereira",
#           "type": 1,
#           "way_points": [
#             213,
#             215
#           ]
#         },
#         {
#           "distance": 97.4,
#           "duration": 11.7,
#           "instruction": "Turn left onto Rua Áurea Lejeune",
#           "name": "Rua Áurea Lejeune",
#           "type": 0,
#           "way_points": [
#             215,
#             216
#           ]
#         },
#         {
#           "distance": 57139.5,
#           "duration": 2671.8,
#           "instruction": "Turn right",
#           "name": "-",
#           "type": 1,
#           "way_points": [
#             216,
#             582
#           ]
#         },
#         {
#           "distance": 427.8,
#           "duration": 30.8,
#           "instruction": "Keep right",
#           "name": "-",
#           "type": 13,
#           "way_points": [
#             582,
#             591
#           ]
#         },
#         {
#           "distance": 2526.0,
#           "duration": 216.3,
#           "instruction": "Continue straight onto Avenida Martins Fontes",
#           "name": "Avenida Martins Fontes",
#           "type": 6,
#           "way_points": [
#             591,
#             619
#           ]
#         },
#         {
#           "distance": 91.8,
#           "duration": 22.0,
#           "instruction": "Turn right onto Rua Tibiriçá",
#           "name": "Rua Tibiriçá",
#           "type": 1,
#           "way_points": [
#             619,
#             621
#           ]
#         },
#         {
#           "distance": 1467.1,
#           "duration": 90.6,
#           "instruction": "Turn left onto Avenida Presidente Wilson",
#           "name": "Avenida Presidente Wilson",
#           "type": 0,
#           "way_points": [
#             621,
#             639
#           ]
#         },
#         {
#           "distance": 2407.2,
#           "duration": 207.2,
#           "instruction": "Turn slight left onto Avenida Ayrton Senna da Silva",
#           "name": "Avenida Ayrton Senna da Silva",
#           "type": 4,
#           "way_points": [
#             639,
#             683
#           ]
#         },
#         {
#           "distance": 170.7,
#           "duration": 15.4,
#           "instruction": "Keep left",
#           "name": "-",
#           "type": 12,
#           "way_points": [
#             683,
#             688
#           ]
#         },
#         {
#           "distance": 417.4,
#           "duration": 27.3,
#           "instruction": "Continue straight onto Avenida Senador Pinheiro Machado",
#           "name": "Avenida Senador Pinheiro Machado",
#           "type": 6,
#           "way_points": [
#             688,
#             694
#           ]
#         },
#         {
#           "distance": 1313.1,
#           "duration": 113.1,
#           "instruction": "Turn right onto Avenida General Francisco Glycerio",
#           "name": "Avenida General Francisco Glycerio",
#           "type": 1,
#           "way_points": [
#             694,
#             709
#           ]
#         },
#         {
#           "distance": 131.9,
#           "duration": 10.6,
#           "instruction": "Keep right onto Rua Bahia",
#           "name": "Rua Bahia",
#           "type": 13,
#           "way_points": [
#             709,
#             713
#           ]
#         },
#         {
#           "distance": 0.0,
#           "duration": 0.0,
#           "instruction": "Arrive at Rua Bahia, on the right",
#           "name": "-",
#           "type": 10,
#           "way_points": [
#             713,
#             713
#           ]
#         }
#       ]
#     }
#   ]
# }
